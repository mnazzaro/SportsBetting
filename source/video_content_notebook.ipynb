# %%
import pandas as pd
import config
import numpy as np
from sklearn.impute import SimpleImputer
from pipeline.training.data_manager import _X_feature_selector, full_set

df = pd.read_csv(f'{config.TRAINING_DATA_PATH}/dataset_with_wl.csv')

# %%
""" This prints out the greatest fighters of all time according to ELO as of their last fight """

latest_fights = df.sort_values(by='date').groupby('fighter_red').tail(1)

latest_fights[['fighter_red', 'elo_red']].sort_values(by='elo_red', ascending=False).head(10)
# Out:
#                  fighter_red      elo_red
# 13050              Jon Jones  1459.471758
# 8097       Georges St-Pierre  1410.694413
# 13090           Kamaru Usman  1380.075794
# 8835      Demetrious Johnson  1372.498448
# 13306  Alexander Volkanovski  1363.886348
# 10901    Khabib Nurmagomedov  1357.388028
# 13394      Aljamain Sterling  1348.973394
# 13351         Dustin Poirier  1333.197571
# 11320           Stipe Miocic  1332.579461
# 10697         Daniel Cormier  1326.804022

# %%
""" This prints out the greatest fighters of all time at the top of their career by max ELO """

max_elo_fighters = df.loc[df.groupby('fighter_red')['elo_red'].idxmax()]

max_elo_fighters[['fighter_red', 'elo_red']].sort_values(by='elo_red', ascending=False).head(25)
# Out:
#                  fighter_red      elo_red
# 13050              Jon Jones  1459.471758
# 8097       Georges St-Pierre  1410.694413
# 12708           Kamaru Usman  1403.051970
# 4168          Anderson Silva  1394.682489
# 13010  Alexander Volkanovski  1387.004382
# 8835      Demetrious Johnson  1372.498448
# 12863        Israel Adesanya  1357.448081
# 10901    Khabib Nurmagomedov  1357.388028
# 13394      Aljamain Sterling  1348.973394
# 7444          Donald Cerrone  1347.983397
# 9850          Daniel Cormier  1346.991138
# 6417           Chris Weidman  1345.854516
# 3122               Jon Fitch  1345.292063
# 12027           Amanda Nunes  1338.829287
# 13351         Dustin Poirier  1333.197571
# 10408          Tony Ferguson  1332.668745
# 11320           Stipe Miocic  1332.579461
# 5947          Cain Velasquez  1323.304667
# 13002        Islam Makhachev  1322.048803
# 7833             Yoel Romero  1321.728546
# 9474            Max Holloway  1319.690574
# 12804       Charles Oliveira  1317.012797
# 11662          Derrick Lewis  1314.617877
# 12097        Francis Ngannou  1314.251531
# 3321            Rashad Evans  1314.109196

# %%
with full_set(df) as (X, y):
    imp = SimpleImputer(missing_values=np.nan, strategy='mean')
    imputed_X = imp.fit_transform(X.select_dtypes(['number']))

    for column in imputed_X.columns:
        print (column)
        imputed_X[column] =  (imputed_X[column] - imputed_X[column].mean()) / (imputed_X[column].std())

    temp = imputed_X[imputed_X['fighter_red'] == 'Alexander Volkanovski']
    temp = temp[temp['date'] == temp['date'].max()].squeeze().sort_values(ascending=True)
# Out:
# /home/markn/.pyenv/versions/3.11.1/lib/python3.11/site-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: invalid value encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 with full_set(df) as (X, y):
#       2     imp = SimpleImputer(missing_values=np.nan, strategy='mean')
# ----> 3     imputed_X = imp.fit_transform(X)
#       5     for column in imputed_X.columns:
#       6         print (column)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/base.py:915, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     911 # non-optimized default implementation; override when a better
#     912 # method is possible for a given clustering algorithm
#     913 if y is None:
#     914     # fit method of arity 1 (unsupervised transformation)
# --> 915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
#     918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/impute/_base.py:366, in SimpleImputer.fit(self, X, y)
#     348 @_fit_context(prefer_skip_nested_validation=True)
#     349 def fit(self, X, y=None):
#     350     """Fit the imputer on `X`.
#     351
#     352     Parameters
#    (...)
#     364         Fitted estimator.
#     365     """
# --> 366     X = self._validate_input(X, in_fit=True)
#     368     # default fill_value is 0 for numerical input and "missing_value"
#     369     # otherwise
#     370     if self.fill_value is None:
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/impute/_base.py:329, in SimpleImputer._validate_input(self, X, in_fit)
#     327         raise new_ve from None
#     328     else:
# --> 329         raise ve
#     331 if in_fit:
#     332     # Use the dtype seen in `fit` for non-`fit` conversion
#     333     self._fit_dtype = X.dtype
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/impute/_base.py:312, in SimpleImputer._validate_input(self, X, in_fit)
#     309     force_all_finite = True
#     311 try:
# --> 312     X = self._validate_data(
#     313         X,
#     314         reset=in_fit,
#     315         accept_sparse="csc",
#     316         dtype=dtype,
#     317         force_all_finite=force_all_finite,
#     318         copy=self.copy,
#     319     )
#     320 except ValueError as ve:
#     321     if "could not convert" in str(ve):
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/utils/validation.py:959, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     953         raise ValueError(
#     954             "Found array with dim %d. %s expected <= 2."
#     955             % (array.ndim, estimator_name)
#     956         )
#     958     if force_all_finite:
# --> 959         _assert_all_finite(
#     960             array,
#     961             input_name=input_name,
#     962             estimator_name=estimator_name,
#     963             allow_nan=force_all_finite == "allow-nan",
#     964         )
#     966 if ensure_min_samples > 0:
#     967     n_samples = _num_samples(array)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/utils/validation.py:124, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     121 if first_pass_isfinite:
#     122     return
# --> 124 _assert_all_finite_element_wise(
#     125     X,
#     126     xp=xp,
#     127     allow_nan=allow_nan,
#     128     msg_dtype=msg_dtype,
#     129     estimator_name=estimator_name,
#     130     input_name=input_name,
#     131 )
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/sklearn/utils/validation.py:173, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     156 if estimator_name and input_name == "X" and has_nan_error:
#     157     # Improve the error message on how to handle missing values in
#     158     # scikit-learn.
#     159     msg_err += (
#     160         f"\n{estimator_name} does not accept missing values"
#     161         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     171         "#estimators-that-handle-nan-values"
#     172     )
# --> 173 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').
